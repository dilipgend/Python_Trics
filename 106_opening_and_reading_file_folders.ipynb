# %%
pwd
# Out:
# 'C:\\Users\\DILIP DASHARATH'

# %%
f = open('practice.txt',"w+")
f.write("this is a test string")
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DILIP DASHARATH'

# %%
os.listdir()
# Out:
# ['.conda',
#  '.condarc',
#  '.continuum',
#  '.imagine1500',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  '100_generators_python.ipynb',
#  '100_generator_python.ipynb',
#  '104_python_collection_modules.ipynb',
#  '11_number.ipynb',
#  '14_variable_assignmenet.ipynb',
#  '15_introduction_to_string.ipynb',
#  '16_string_slicing.ipynb',
#  '17String_properties_an_method.ipynb',
#  '19_string_formating.ipynb',
#  '34_elif_condition.ipynb',
#  '35_for_input_table.ipynb',
#  '35_for_loop.ipynb',
#  '36_while_loop.ipynb',
#  '36_while_loop_table.ipynb',
#  '41_ython_documantation.ipynb',
#  '44_basic_python_function.ipynb',
#  '45_logic_with_python_function.ipynb',
#  '47_interaction_between_python_function.ipynb',
#  '49__args_kwargs.ipynb',
#  '55lambada_map_and_filter.ipynb',
#  '56_nested_statement and scope.ipynb',
#  '58_methods_and_function.ipynb',
#  '60_displaying_information.ipynb',
# ...

# %%
import shutil

# %%
shutil.move('practice.txt','C:\\Users\\New folder')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\anaconda3\lib\shutil.py:823, in move(src, dst, copy_function)
#     822 try:
# --> 823     os.rename(src, real_dst)
#     824 except OSError:
#
# PermissionError: [WinError 5] Access is denied: 'practice.txt' -> 'C:\\Users\\New folder\\practice.txt'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 shutil.move('practice.txt','C:\\Users\\New folder')
#
# File ~\anaconda3\lib\shutil.py:843, in move(src, dst, copy_function)
#     841         rmtree(src)
#     842     else:
# --> 843         copy_function(src, real_dst)
#     844         os.unlink(src)
#     845 return real_dst
#
# File ~\anaconda3\lib\shutil.py:444, in copy2(src, dst, follow_symlinks)
# ...

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.conda',
#  '.condarc',
#  '.continuum',
#  '.imagine1500',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  '100_generators_python.ipynb',
#  '100_generator_python.ipynb',
#  '104_python_collection_modules.ipynb',
#  '11_number.ipynb',
#  '14_variable_assignmenet.ipynb',
#  '15_introduction_to_string.ipynb',
#  '16_string_slicing.ipynb',
#  '17String_properties_an_method.ipynb',
#  '19_string_formating.ipynb',
#  '34_elif_condition.ipynb',
#  '35_for_input_table.ipynb',
#  '35_for_loop.ipynb',
#  '36_while_loop.ipynb',
#  '36_while_loop_table.ipynb',
#  '41_ython_documantation.ipynb',
#  '44_basic_python_function.ipynb',
#  '45_logic_with_python_function.ipynb',
#  '47_interaction_between_python_function.ipynb',
#  '49__args_kwargs.ipynb',
#  '55lambada_map_and_filter.ipynb',
#  '56_nested_statement and scope.ipynb',
#  '58_methods_and_function.ipynb',
#  '60_displaying_information.ipynb',
# ...

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.conda',
#  '.condarc',
#  '.continuum',
#  '.imagine1500',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  '100_generators_python.ipynb',
#  '100_generator_python.ipynb',
#  '104_python_collection_modules.ipynb',
#  '11_number.ipynb',
#  '14_variable_assignmenet.ipynb',
#  '15_introduction_to_string.ipynb',
#  '16_string_slicing.ipynb',
#  '17String_properties_an_method.ipynb',
#  '19_string_formating.ipynb',
#  '34_elif_condition.ipynb',
#  '35_for_input_table.ipynb',
#  '35_for_loop.ipynb',
#  '36_while_loop.ipynb',
#  '36_while_loop_table.ipynb',
#  '41_ython_documantation.ipynb',
#  '44_basic_python_function.ipynb',
#  '45_logic_with_python_function.ipynb',
#  '47_interaction_between_python_function.ipynb',
#  '49__args_kwargs.ipynb',
#  '55lambada_map_and_filter.ipynb',
#  '56_nested_statement and scope.ipynb',
#  '58_methods_and_function.ipynb',
#  '60_displaying_information.ipynb',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DILIP DASHARATH'

# %%
file_path = 'C:\\Users\\DILIP DASHARATH\\Untitled65'

# %%
for folder, subfolder, files in os.walk(file_path):
    
    print(f"Currently looking at {folder}")
    print("\n")
    print("the subfolders are :  ")
    for subfold in subfolder:
        print(f"\t Subfolder : {subfold}")
        
        
    print("\n")
    print("the files are : ")
    for f in files:
        print(f"\t file : {f}")
    print("\n")
