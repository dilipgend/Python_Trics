# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x468 at 0x239C898EAF0>

# %%
mac.show()

# %%
mac.size
# Out:
# (711, 468)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x239C8A10760>

# %%
pencils = Image.open('Adhar.jpg')

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=717x483 at 0x239CB4FE310>

# %%
pencils.size
# Out:
# (717, 483)

# %%
x = 0
y = 0

w = 717/3
h = 483/10

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=239x48 at 0x239CC0CEF10>

# %%
x = 0
y = 512

w = 717/3
h = 600

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=239x88 at 0x239CC0F5040>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x468 at 0x239C898EAF0>

# %%
mac.size
# Out:
# (711, 468)

# %%
halfway = 711/2

# %%
x = halfway - 200
w = halfway + 200

# %%
y = 200
h = 468

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=400x268 at 0x239CB22AF40>

# %%
licence = mac.crop((x,y,w,h))

# %%
mac.paste(im=licence,box=(0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x468 at 0x239C898EAF0>

# %%
mac.resize((1200,1000))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1000 at 0x239CC0F5B80>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=711x468 at 0x239CB1F4B20>
