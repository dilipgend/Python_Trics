# %%
from PIL import Image

# %%
words = Image.open("word_matrix.png")

# %%
mask = Image.open("mask.png")

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=717x483 at 0x17FECF05F10>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=711x468 at 0x17FECF00F70>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 mask.paste(words,(0,0),words)
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:1557, in Image.paste(self, im, box, mask)
#    1555 if mask:
#    1556     mask.load()
# -> 1557     self.im.paste(im, box, mask.im)
#    1558 else:
#    1559     self.im.paste(im, box)
#
# ValueError: bad transparency mask

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=717x483 at 0x17FECF05F10>

# %%
mask.size
# Out:
# (711, 468)

# %%
mask = mask.resize((1015,599))

# %%
mask.size
# Out:
# (1015, 599)

# %%
#mask.putalpha(200)
